# %% [markdown]
# ##libraries

# %%
import pandas as pd
import requests
import os

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}
base_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_"

# %% [markdown]
# ## check how many files are required to make up 30 GB

# %%
target_gb = 30
target_bytes = target_gb * 1024 * 1024 * 1024

start_date = '2009-01-01'
end_date = '2024-05-01'
months_range = pd.date_range(start=start_date, end=end_date, freq='MS')
months_to_process = [d.strftime('%Y-%m') for d in months_range]

monthly_file_info = []
total_accumulated_bytes = 0

print(f"Searching for files to reach {target_gb} GB target...")

for month in months_to_process:
    if total_accumulated_bytes >= target_bytes:
        break

    file_url = f"{base_url}{month}.parquet"
    try:
        response = requests.get(file_url, headers=headers, stream=True, timeout=10)
        if response.status_code == 200:
            file_size = int(response.headers.get('Content-Length', 0))
            total_accumulated_bytes += file_size
            monthly_file_info.append({'month': month, 'size_mb': file_size / (1024**2)})
            print(f"Found {month}: {file_size / (1024**2):.2f} MB | Total: {total_accumulated_bytes / (1024**3):.2f} GB")
    except:
        continue

print(f"\nTotal Months discovered: {len(monthly_file_info)}")
print(f"Total Size: {total_accumulated_bytes / (1024**3):.2f} GB")
# Out:
# Searching for files to reach 30 GB target...
# Found 2009-01: 448.00 MB | Total: 0.44 GB
# Found 2009-02: 422.89 MB | Total: 0.85 GB
# Found 2009-03: 460.24 MB | Total: 1.30 GB
# Found 2009-04: 455.98 MB | Total: 1.75 GB
# Found 2009-05: 472.38 MB | Total: 2.21 GB
# Found 2009-06: 451.65 MB | Total: 2.65 GB
# Found 2009-07: 433.55 MB | Total: 3.07 GB
# Found 2009-08: 437.04 MB | Total: 3.50 GB
# Found 2009-09: 446.65 MB | Total: 3.93 GB
# Found 2009-10: 503.09 MB | Total: 4.43 GB
# Found 2009-11: 456.15 MB | Total: 4.87 GB
# Found 2009-12: 465.00 MB | Total: 5.32 GB
# Found 2010-01: 491.53 MB | Total: 5.80 GB
# Found 2010-02: 342.10 MB | Total: 6.14 GB
# Found 2010-03: 389.78 MB | Total: 6.52 GB
# Found 2010-04: 503.83 MB | Total: 7.01 GB
# Found 2010-05: 516.69 MB | Total: 7.52 GB
# Found 2010-06: 493.55 MB | Total: 8.00 GB
# Found 2010-07: 487.32 MB | Total: 8.47 GB
# Found 2010-08: 378.74 MB | Total: 8.84 GB
# Found 2010-09: 484.66 MB | Total: 9.32 GB
# Found 2010-10: 452.64 MB | Total: 9.76 GB
# Found 2010-11: 427.63 MB | Total: 10.18 GB
# Found 2010-12: 424.10 MB | Total: 10.59 GB
# Found 2011-01: 159.44 MB | Total: 10.75 GB
# Found 2011-02: 167.83 MB | Total: 10.91 GB
# Found 2011-03: 190.67 MB | Total: 11.10 GB
# Found 2011-04: 175.66 MB | Total: 11.27 GB
# Found 2011-05: 184.47 MB | Total: 11.45 GB
# Found 2011-06: 180.36 MB | Total: 11.62 GB
# Found 2011-07: 175.50 MB | Total: 11.80 GB
# Found 2011-08: 158.51 MB | Total: 11.95 GB
# Found 2011-09: 174.99 MB | Total: 12.12 GB
# Found 2011-10: 187.18 MB | Total: 12.30 GB
://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{month_target}.parquet"
temp_file = f"temp_{month_target}_time.parquet"

print(f"Downloading {month_target} data for day/night analysis.")
response = requests.get(file_url)
with open(temp_file, 'wb') as f:
    f.write(response.content)

# Load only the pickup datetime column
df_time = pd.read_parquet(temp_file, columns=['tpep_pickup_datetime'])

# Extract the hour
hour = df_time['tpep_pickup_datetime'].dt.hour

# Define Day (6am to 6pm) vs Night
# Day: 6, 7, ..., 17 | Night: 18, 19, ..., 5
df_time['time_of_day'] = 'Night'
df_time.loc[(hour >= 6) & (hour < 18), 'time_of_day'] = 'Day'

# Calculate counts
time_counts = df_time['time_of_day'].value_counts()

print(f"\nDay vs. Night Trip Counts for {month_target}")
print(time_counts)
print(f"\nPercentage Day: {(time_counts['Day'] / len(df_time) * 100):.2f}%")

# Cleanup
os.remove(temp_file)
del df_time
# Out:
# Downloading 2014-01 data for day/night analysis.
#
# Day vs. Night Trip Counts for 2014-01
# time_of_day
# Day      7364425
# Night    6418092
# Name: count, dtype: int64
#
# Percentage Day: 53.43%

# %% [markdown]
# ### check payment type distribution

# %%
month_target = "2014-01"
file_url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{month_target}.parquet"
temp_file = f"temp_{month_target}_payment.parquet"

print(f"Downloading {month_target} data for payment analysis.")
response = requests.get(file_url)
with open(temp_file, 'wb') as f:
    f.write(response.content)

df_pay = pd.read_parquet(temp_file, columns=['payment_type'])

payment_map = {
    1: 'Credit Card',
    2: 'Cash',
    3: 'No Charge',
    4: 'Dispute',
    5: 'Unknown',
    6: 'Void'
}
df_pay['payment_label'] = df_pay['payment_type'].map(payment_map)


payment_counts = df_pay['payment_label'].value_counts()

print(f"\nPayment Type Distribution for {month_target}")
print(payment_counts)

os.remove(temp_file)
del df_pay
# Out:
# Downloading 2014-01 data for payment analysis.
#
# Payment Type Distribution for 2014-01
# payment_label
# Credit Card    7855148
# Cash           5818066
# Unknown          67880
# No Charge        32076
# Dispute           9347
# Name: count, dtype: int64

# %% [markdown]
# ### check trips per passenger count

# %%
month_target = "2014-01"
file_url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{month_target}.parquet"
temp_file = f"temp_{month_target}_passengers.parquet"

print(f"Downloading {month_target} data for passenger count analysis.")
response = requests.get(file_url)
with open(temp_file, 'wb') as f:
    f.write(response.content)

# Load the passenger_count column
df_pass = pd.read_parquet(temp_file, columns=['passenger_count'])

# Calculate frequency of each passenger count
passenger_dist = df_pass['passenger_count'].value_counts().sort_index()

print(f"\nPassenger Count Distribution for {month_target}")
print(passenger_dist)

# Cleanup
os.remove(temp_file)
del df_pass
# Out:
# Downloading 2014-01 data for passenger count analysis.
#
# Passenger Count Distribution for 2014-01
# passenger_count
# 0          259
# 1      9727321
# 2      1891588
# 3       566248
# 4       267540
# 5       789070
# 6       540444
# 7            7
# 8            5
# 9           16
# 208         19
# Name: count, dtype: int64

# %% [markdown]
# ###check RateCode

# %%
month_target = "2014-01"
file_url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{month_target}.parquet"
temp_file = f"temp_{month_target}_ratecode.parquet"

print(f"Downloading {month_target} data for rate code analysis.")
response = requests.get(file_url)
with open(temp_file, 'wb') as f:
    f.write(response.content)


df_rate = pd.read_parquet(temp_file, columns=['RatecodeID'])

rate_map = {
    1.0: 'Standard Rate',
    2.0: 'JFK',
    3.0: 'Newark',
    4.0: 'Nassau/Westchester',
    5.0: 'Negotiated Fare',
    6.0: 'Group Ride'
}

df_rate['rate_label'] = df_rate['RatecodeID'].map(rate_map)
rate_counts = df_rate['rate_label'].value_counts()

print(f"\nRate Code Distribution for {month_target}")
print(rate_counts)

os.remove(temp_file)
del df_rate
# Out:
# Downloading 2014-01 data for rate code analysis.
#
# Rate Code Distribution for 2014-01
# rate_label
# Standard Rate         13490929
# JFK                     227834
# Negotiated Fare          38130
# Newark                   19380
# Nassau/Westchester        4550
# Group Ride                 145
# Name: count, dtype: int64

# %% [markdown]
# ##download .parquet files

# %%
# Configuration
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}
base_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_"

# Define the range for 2024 and 2025
years = [2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025]
months = range(1, 13)

print("Starting extraction for 2014 and 2025 data...")

for year in years:
    for month in months:
        month_str = f"{year}-{month:02d}"
        file_name = f"yellow_tripdata_{month_str}.parquet"
        file_url = f"{base_url}{month_str}.parquet"

        try:
            # Check if file already exists
            if os.path.exists(file_name):
                print(f"File {file_name} already exists. Skipping.")
                continue

            # Attempt to download
            response = requests.get(file_url, headers=headers, stream=True)

            if response.status_code == 200:
                with open(file_name, 'wb') as f:
                    f.write(response.content)
                print(f"Successfully saved: {file_name} ({len(response.content)/(1024**2):.2f} MB)")
            elif response.status_code == 403 or response.status_code == 404:
                # This is expected for future months not yet released by TLC
                pass
            else:
                print(f"Could not download {month_str}: Status {response.status_code}")

        except Exception as e:
            print(f"Error processing {month_str}: {e}")

print("\nProcess complete. Check the file explorer on the left to see your saved files.")
# Out:
# Starting extraction for 2024 and 2025 data...
# Successfully saved: yellow_tripdata_2014-01.parquet (164.01 MB)
# Successfully saved: yellow_tripdata_2014-02.parquet (154.69 MB)
# Successfully saved: yellow_tripdata_2014-03.parquet (183.52 MB)
# Successfully saved: yellow_tripdata_2014-04.parquet (174.71 MB)
# Successfully saved: yellow_tripdata_2014-05.parquet (178.05 MB)
# Successfully saved: yellow_tripdata_2014-06.parquet (165.78 MB)
# Successfully saved: yellow_tripdata_2014-07.parquet (157.46 MB)
# Successfully saved: yellow_tripdata_2014-08.parquet (165.17 MB)
# Successfully saved: yellow_tripdata_2014-09.parquet (175.34 MB)
# Successfully saved: yellow_tripdata_2014-10.parquet (186.59 MB)
# Successfully saved: yellow_tripdata_2014-11.parquet (172.70 MB)
# Successfully saved: yellow_tripdata_2014-12.parquet (170.71 MB)
# Successfully saved: yellow_tripdata_2015-01.parquet (167.20 MB)
# Successfully saved: yellow_tripdata_2015-02.parquet (163.69 MB)
# Successfully saved: yellow_tripdata_2015-03.parquet (176.77 MB)
# Successfully saved: yellow_tripdata_2015-04.parquet (172.13 MB)
# Successfully saved: yellow_tripdata_2015-05.parquet (174.03 MB)
# Successfully saved: yellow_tripdata_2015-06.parquet (163.80 MB)
# Successfully saved: yellow_tripdata_2015-07.parquet (153.25 MB)
# Successfully saved: yellow_tripdata_2015-08.parquet (147.10 MB)
# Successfully saved: yellow_tripdata_2015-09.parquet (149.16 MB)
# Successfully saved: yellow_tripdata_2015-10.parquet (163.17 MB)
# Successfully saved: yellow_tripdata_2015-11.parquet (150.36 MB)
# Successfully saved: yellow_tripdata_2015-12.parquet (152.50 MB)
# Successfully saved: yellow_tripdata_2016-01.parquet (144.24 MB)
# Successfully saved: yellow_tripdata_2016-02.parquet (150.79 MB)
# Successfully saved: yellow_tripdata_2016-03.parquet (162.14 MB)
# Successfully saved: yellow_tripdata_2016-04.parquet (157.88 MB)
# Successfully saved: yellow_tripdata_2016-05.parquet (158.13 MB)
# Successfully saved: yellow_tripdata_2016-06.parquet (149.05 MB)
# Successfully saved: yellow_tripdata_2016-07.parquet (137.92 MB)
# Successfully saved: yellow_tripdata_2016-08.parquet (133.40 MB)
# Successfully saved: yellow_tripdata_2016-09.parquet (135.28 MB)
# Successfully saved: yellow_tripdata_2016-10.parquet (145.51 MB)
# Successfully saved: yellow_tripdata_2016-11.parquet (134.61 MB)
# Successfully saved: yellow_tripdata_2016-12.parquet (139.20 MB)
# Successfully saved: yellow_tripdata_2017-01.parquet (128.58 MB)
# Successfully saved: yellow_tripdata_2017-02.parquet (121.73 MB)
# Successfully saved: yellow_tripdata_2017-03.parquet (137.88 MB)
# Successfully saved: yellow_tripdata_2017-04.parquet (134.80 MB)
# Successfully saved: yellow_tripdata_2017-05.parquet (135.78 MB)
# Successfully saved: yellow_tripdata_2017-06.parquet (129.21 MB)
# Successfully saved: yellow_tripdata_2017-07.parquet (115.24 MB)
# Successfully saved: yellow_tripdata_2017-08.parquet (113.13 MB)
# Successfully saved: yellow_tripdata_2017-09.parquet (121.02 MB)
# Successfully saved: yellow_tripdata_2017-10.parquet (130.41 MB)
# Successfully saved: yellow_tripdata_2017-11.parquet (124.99 MB)
# Successfully saved: yellow_tripdata_2017-12.parquet (128.04 MB)
# Successfully saved: yellow_tripdata_2018-01.parquet (117.94 MB)
# Successfully saved: yellow_tripdata_2018-02.parquet (113.92 MB)
# Successfully saved: yellow_tripdata_2018-03.parquet (127.37 MB)
# Successfully saved: yellow_tripdata_2018-04.parquet (125.51 MB)
# Successfully saved: yellow_tripdata_2018-05.parquet (124.79 MB)
# Successfully saved: yellow_tripdata_2018-06.parquet (118.44 MB)
# Successfully saved: yellow_tripdata_2018-07.parquet (107.04 MB)
# Successfully saved: yellow_tripdata_2018-08.parquet (106.26 MB)
# Successfully saved: yellow_tripdata_2018-09.parquet (110.15 MB)
# Successfully saved: yellow_tripdata_2018-10.parquet (121.02 MB)
# Successfully saved: yellow_tripdata_2018-11.parquet (111.74 MB)
# Successfully saved: yellow_tripdata_2018-12.parquet (112.39 MB)
# Successfully saved: yellow_tripdata_2019-01.parquet (105.32 MB)
# Successfully saved: yellow_tripdata_2019-02.parquet (98.57 MB)
# Successfully saved: yellow_tripdata_2019-03.parquet (110.64 MB)
# Successfully saved: yellow_tripdata_2019-04.parquet (105.04 MB)
# Successfully saved: yellow_tripdata_2019-05.parquet (106.31 MB)
# Successfully saved: yellow_tripdata_2019-06.parquet (98.14 MB)
# Successfully saved: yellow_tripdata_2019-07.parquet (89.53 MB)
# Successfully saved: yellow_tripdata_2019-08.parquet (85.83 MB)
# Successfully saved: yellow_tripdata_2019-09.parquet (92.61 MB)
# Successfully saved: yellow_tripdata_2019-10.parquet (101.37 MB)
# Successfully saved: yellow_tripdata_2019-11.parquet (96.20 MB)
# Successfully saved: yellow_tripdata_2019-12.parquet (96.36 MB)
# Successfully saved: yellow_tripdata_2020-01.parquet (89.23 MB)
# Successfully saved: yellow_tripdata_2020-02.parquet (87.87 MB)
# Successfully saved: yellow_tripdata_2020-03.parquet (42.38 MB)
# Successfully saved: yellow_tripdata_2020-04.parquet (4.24 MB)
# Successfully saved: yellow_tripdata_2020-05.parquet (5.94 MB)
# Successfully saved: yellow_tripdata_2020-06.parquet (9.07 MB)
# Successfully saved: yellow_tripdata_2020-07.parquet (12.77 MB)
# Successfully saved: yellow_tripdata_2020-08.parquet (15.83 MB)
# Successfully saved: yellow_tripdata_2020-09.parquet (20.39 MB)
# Successfully saved: yellow_tripdata_2020-10.parquet (25.09 MB)
# Successfully saved: yellow_tripdata_2020-11.parquet (22.49 MB)
# Successfully saved: yellow_tripdata_2020-12.parquet (21.95 MB)
# File yellow_tripdata_2021-01.parquet already exists. Skipping.
# File yellow_tripdata_2021-02.parquet already exists. Skipping.
# File yellow_tripdata_2021-03.parquet already exists. Skipping.
# File yellow_tripdata_2021-04.parquet already exists. Skipping.
# File yellow_tripdata_2021-05.parquet already exists. Skipping.
# File yellow_tripdata_2021-06.parquet already exists. Skipping.
# File yellow_tripdata_2021-07.parquet already exists. Skipping.
# File yellow_tripdata_2021-08.parquet already exists. Skipping.
# File yellow_tripdata_2021-09.parquet already exists. Skipping.
# File yellow_tripdata_2021-10.parquet already exists. Skipping.
# File yellow_tripdata_2021-11.parquet already exists. Skipping.
# File yellow_tripdata_2021-12.parquet already exists. Skipping.
# File yellow_tripdata_2022-01.parquet already exists. Skipping.
# File yellow_tripdata_2022-02.parquet already exists. Skipping.
# File yellow_tripdata_2022-03.parquet already exists. Skipping.
# File yellow_tripdata_2022-04.parquet already exists. Skipping.
# File yellow_tripdata_2022-05.parquet already exists. Skipping.
# File yellow_tripdata_2022-06.parquet already exists. Skipping.
# File yellow_tripdata_2022-07.parquet already exists. Skipping.
# File yellow_tripdata_2022-08.parquet already exists. Skipping.
# File yellow_tripdata_2022-09.parquet already exists. Skipping.
# File yellow_tripdata_2022-10.parquet already exists. Skipping.
# File yellow_tripdata_2022-11.parquet already exists. Skipping.
# File yellow_tripdata_2022-12.parquet already exists. Skipping.
# File yellow_tripdata_2023-01.parquet already exists. Skipping.
# File yellow_tripdata_2023-02.parquet already exists. Skipping.
# File yellow_tripdata_2023-03.parquet already exists. Skipping.
# File yellow_tripdata_2023-04.parquet already exists. Skipping.
# File yellow_tripdata_2023-05.parquet already exists. Skipping.
# File yellow_tripdata_2023-06.parquet already exists. Skipping.
# File yellow_tripdata_2023-07.parquet already exists. Skipping.
# File yellow_tripdata_2023-08.parquet already exists. Skipping.
# File yellow_tripdata_2023-09.parquet already exists. Skipping.
# File yellow_tripdata_2023-10.parquet already exists. Skipping.
# File yellow_tripdata_2023-11.parquet already exists. Skipping.
# File yellow_tripdata_2023-12.parquet already exists. Skipping.
# File yellow_tripdata_2024-01.parquet already exists. Skipping.
# File yellow_tripdata_2024-02.parquet already exists. Skipping.
# File yellow_tripdata_2024-03.parquet already exists. Skipping.
# File yellow_tripdata_2024-04.parquet already exists. Skipping.
# File yellow_tripdata_2024-05.parquet already exists. Skipping.
# File yellow_tripdata_2024-06.parquet already exists. Skipping.
# File yellow_tripdata_2024-07.parquet already exists. Skipping.
# File yellow_tripdata_2024-08.parquet already exists. Skipping.
# File yellow_tripdata_2024-09.parquet already exists. Skipping.
# File yellow_tripdata_2024-10.parquet already exists. Skipping.
# File yellow_tripdata_2024-11.parquet already exists. Skipping.
# File yellow_tripdata_2024-12.parquet already exists. Skipping.
# File yellow_tripdata_2025-01.parquet already exists. Skipping.
# File yellow_tripdata_2025-02.parquet already exists. Skipping.
# File yellow_tripdata_2025-03.parquet already exists. Skipping.
# File yellow_tripdata_2025-04.parquet already exists. Skipping.
# File yellow_tripdata_2025-05.parquet already exists. Skipping.
# File yellow_tripdata_2025-06.parquet already exists. Skipping.
# File yellow_tripdata_2025-07.parquet already exists. Skipping.
# File yellow_tripdata_2025-08.parquet already exists. Skipping.
# File yellow_tripdata_2025-09.parquet already exists. Skipping.
# File yellow_tripdata_2025-10.parquet already exists. Skipping.
# File yellow_tripdata_2025-11.parquet already exists. Skipping.
# File yellow_tripdata_2025-12.parquet already exists. Skipping.
#
# Process complete. Check the file explorer on the left to see your saved files.

# %% [markdown]
# ## check which years selected would make up around 12GB+

# %%
# Define the years requested
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]

all_files = []
for year in years:
    # Find all monthly parquet files for the specific year
    all_files.extend(glob.glob(f'yellow_tripdata_{year}-*.parquet'))

# Calculate total size
total_bytes = sum(os.path.getsize(f) for f in all_files)
total_gb = total_bytes / (1024**3)
total_mb = total_bytes / (1024**2)

print(f"Number of files found: {len(all_files)}")
print(f"Years included: {min(years)} to {max(years)}")
print(f"Total combined size: {total_mb:.2f} MB ({total_gb:.2f} GB)")
# Out:
# Number of files found: 144
# Years included: 2014 to 2025
# Total combined size: 13242.45 MB (12.93 GB)

# %% [markdown]
# ## download the files for taxi trips that took place between 20:00pm till 5:00am

# %%
all_local_files = glob.glob('yellow_tripdata_*.parquet')

for file_path in all_local_files:
    try:

        df = pd.read_parquet(file_path)


        pickup_col = 'tpep_pickup_datetime' if 'tpep_pickup_datetime' in df.columns else 'Trip_Pickup_DateTime'

        if pickup_col not in df.columns:
            print(f"Warning: No datetime column found in {file_path}. Skipping.")
            continue


        df[pickup_col] = pd.to_datetime(df[pickup_col])

        hours = df[pickup_col].dt.hour
        night_df = df[(hours >= 20) | (hours < 5)].copy()


        night_df.to_parquet(file_path, index=False)

        reduction = (1 - len(night_df)/len(df)) * 100
        print(f"Processed {file_path}: Kept {len(night_df):,} trips (Reduced by {reduction:.1f}%)")

        del df
        del night_df

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

print("\nFiltering complete. All files now contain only night-time trips.")
# Out:
# Starting filtering for 144 files...
# Processed yellow_tripdata_2025-11.parquet: Kept 1,243,520 trips (Reduced by 32.0%)
# Processed yellow_tripdata_2021-08.parquet: Kept 694,685 trips (Reduced by 36.6%)
# Processed yellow_tripdata_2023-10.parquet: Kept 1,000,022 trips (Reduced by 33.3%)
# Processed yellow_tripdata_2014-10.parquet: Kept 4,846,346 trips (Reduced by 28.3%)
# Processed yellow_tripdata_2025-10.parquet: Kept 1,312,416 trips (Reduced by 32.7%)
# Processed yellow_tripdata_2025-04.parquet: Kept 1,159,818 trips (Reduced by 70.8%)
# Processed yellow_tripdata_2015-01.parquet: Kept 4,158,740 trips (Reduced by 67.4%)
# Processed yellow_tripdata_2018-11.parquet: Kept 2,361,214 trips (Reduced by 71.0%)
# Processed yellow_tripdata_2025-09.parquet: Kept 1,298,720 trips (Reduced by 69.4%)
# Processed yellow_tripdata_2017-01.parquet: Kept 2,943,813 trips (Reduced by 69.7%)
# Processed yellow_tripdata_2017-12.parquet: Kept 2,950,416 trips (Reduced by 69.0%)
# Processed yellow_tripdata_2017-11.parquet: Kept 2,788,686 trips (Reduced by 70.0%)
# Processed yellow_tripdata_2017-06.parquet: Kept 3,043,716 trips (Reduced by 68.5%)
# Processed yellow_tripdata_2017-07.parquet: Kept 2,752,393 trips (Reduced by 68.0%)
# Processed yellow_tripdata_2021-03.parquet: Kept 301,171 trips (Reduced by 84.4%)
# Processed yellow_tripdata_2015-08.parquet: Kept 3,798,919 trips (Reduced by 65.8%)
# Processed yellow_tripdata_2021-11.parquet: Kept 893,422 trips (Reduced by 74.3%)
# Processed yellow_tripdata_2021-07.parquet: Kept 700,069 trips (Reduced by 75.2%)
# Processed yellow_tripdata_2024-01.parquet: Kept 785,216 trips (Reduced by 73.5%)
# Processed yellow_tripdata_2025-12.parquet: Kept 1,280,783 trips (Reduced by 70.2%)
# Processed yellow_tripdata_2016-05.parquet: Kept 3,848,722 trips (Reduced by 67.5%)
# Processed yellow_tripdata_2024-08.parquet: Kept 828,500 trips (Reduced by 72.2%)
# Processed yellow_tripdata_2017-09.parquet: Kept 2,782,960 trips (Reduced by 68.9%)
# Processed yellow_tripdata_2014-08.parquet: Kept 4,480,101 trips (Reduced by 64.7%)
# Processed yellow_tripdata_2025-03.parquet: Kept 1,325,010 trips (Reduced by 68.0%)
# Processed yellow_tripdata_2020-02.parquet: Kept 1,753,769 trips (Reduced by 72.2%)
# Processed yellow_tripdata_2014-09.parquet: Kept 4,573,742 trips (Reduced by 65.9%)
# Processed yellow_tripdata_2024-12.parquet: Kept 1,045,109 trips (Reduced by 71.5%)
# Processed yellow_tripdata_2018-04.parquet: Kept 2,763,238 trips (Reduced by 70.3%)
# Processed yellow_tripdata_2019-12.parquet: Kept 1,999,860 trips (Reduced by 71.0%)
# Processed yellow_tripdata_2017-08.parquet: Kept 2,586,716 trips (Reduced by 69.3%)
# Processed yellow_tripdata_2023-08.parquet: Kept 779,000 trips (Reduced by 72.4%)
# Processed yellow_tripdata_2018-05.parquet: Kept 2,724,123 trips (Reduced by 70.5%)
# Processed yellow_tripdata_2024-10.parquet: Kept 1,113,256 trips (Reduced by 71.0%)
# Processed yellow_tripdata_2016-04.parquet: Kept 3,936,602 trips (Reduced by 67.0%)
# Processed yellow_tripdata_2022-11.parquet: Kept 875,752 trips (Reduced by 73.1%)
# Processed yellow_tripdata_2014-03.parquet: Kept 5,256,647 trips (Reduced by 65.9%)
# Processed yellow_tripdata_2019-03.parquet: Kept 2,333,704 trips (Reduced by 70.3%)
# Processed yellow_tripdata_2019-09.parquet: Kept 1,908,777 trips (Reduced by 70.9%)
# Processed yellow_tripdata_2022-09.parquet: Kept 885,317 trips (Reduced by 72.2%)
# Processed yellow_tripdata_2022-05.parquet: Kept 963,977 trips (Reduced by 73.1%)
# Processed yellow_tripdata_2023-09.parquet: Kept 793,809 trips (Reduced by 72.1%)
# Processed yellow_tripdata_2023-04.parquet: Kept 925,854 trips (Reduced by 71.8%)
# Processed yellow_tripdata_2020-05.parquet: Kept 60,033 trips (Reduced by 82.8%)
# Processed yellow_tripdata_2023-11.parquet: Kept 925,321 trips (Reduced by 72.3%)
# Processed yellow_tripdata_2018-10.parquet: Kept 2,594,690 trips (Reduced by 70.6%)
# Processed yellow_tripdata_2020-09.parquet: Kept 222,169 trips (Reduced by 83.4%)
# Processed yellow_tripdata_2020-07.parquet: Kept 137,096 trips (Reduced by 82.9%)
# Processed yellow_tripdata_2015-04.parquet: Kept 4,352,286 trips (Reduced by 66.7%)
# Processed yellow_tripdata_2015-12.parquet: Kept 3,822,669 trips (Reduced by 66.6%)
# Processed yellow_tripdata_2014-04.parquet: Kept 4,947,535 trips (Reduced by 66.2%)
# Processed yellow_tripdata_2016-10.parquet: Kept 3,505,632 trips (Reduced by 67.7%)
# Processed yellow_tripdata_2019-07.parquet: Kept 1,798,770 trips (Reduced by 71.5%)
# Processed yellow_tripdata_2023-07.parquet: Kept 832,354 trips (Reduced by 71.4%)
# Processed yellow_tripdata_2018-03.parquet: Kept 2,811,208 trips (Reduced by 70.2%)
# Processed yellow_tripdata_2023-05.parquet: Kept 978,558 trips (Reduced by 72.1%)
# Processed yellow_tripdata_2019-01.parquet: Kept 2,090,066 trips (Reduced by 72.8%)
# Processed yellow_tripdata_2021-05.parquet: Kept 523,132 trips (Reduced by 79.1%)
# Processed yellow_tripdata_2025-08.parquet: Kept 1,079,323 trips (Reduced by 69.8%)
# Processed yellow_tripdata_2020-08.parquet: Kept 181,686 trips (Reduced by 82.0%)
# Processed yellow_tripdata_2023-12.parquet: Kept 979,096 trips (Reduced by 71.0%)
# Processed yellow_tripdata_2022-02.parquet: Kept 770,010 trips (Reduced by 74.2%)
# Processed yellow_tripdata_2022-04.parquet: Kept 961,058 trips (Reduced by 73.3%)
# Processed yellow_tripdata_2019-04.parquet: Kept 2,144,193 trips (Reduced by 71.3%)
# Processed yellow_tripdata_2022-08.parquet: Kept 845,796 trips (Reduced by 73.2%)
# Processed yellow_tripdata_2015-02.parquet: Kept 4,084,277 trips (Reduced by 67.2%)
# Processed yellow_tripdata_2021-02.parquet: Kept 188,057 trips (Reduced by 86.3%)
# Processed yellow_tripdata_2016-06.parquet: Kept 3,700,382 trips (Reduced by 66.8%)
# Processed yellow_tripdata_2020-04.parquet: Kept 32,858 trips (Reduced by 86.2%)
# Processed yellow_tripdata_2024-03.parquet: Kept 1,067,713 trips (Reduced by 70.2%)
# Processed yellow_tripdata_2019-05.parquet: Kept 2,191,432 trips (Reduced by 71.2%)
# Processed yellow_tripdata_2016-01.parquet: Kept 3,515,600 trips (Reduced by 67.8%)
# Processed yellow_tripdata_2018-02.parquet: Kept 2,451,668 trips (Reduced by 71.1%)
# Processed yellow_tripdata_2020-01.parquet: Kept 1,737,021 trips (Reduced by 72.9%)
# Processed yellow_tripdata_2018-12.parquet: Kept 2,446,522 trips (Reduced by 70.1%)
# Processed yellow_tripdata_2020-12.parquet: Kept 187,648 trips (Reduced by 87.2%)
# Processed yellow_tripdata_2025-02.parquet: Kept 1,081,907 trips (Reduced by 69.8%)
# Processed yellow_tripdata_2025-05.parquet: Kept 1,394,709 trips (Reduced by 69.6%)
# Processed yellow_tripdata_2021-09.parquet: Kept 757,576 trips (Reduced by 74.4%)
# Processed yellow_tripdata_2014-02.parquet: Kept 4,488,391 trips (Reduced by 65.6%)
# Processed yellow_tripdata_2017-02.parquet: Kept 2,863,373 trips (Reduced by 68.8%)
# Processed yellow_tripdata_2022-06.parquet: Kept 977,361 trips (Reduced by 72.5%)
# Processed yellow_tripdata_2022-03.parquet: Kept 950,879 trips (Reduced by 73.8%)
# Processed yellow_tripdata_2024-06.parquet: Kept 1,040,564 trips (Reduced by 70.6%)
# Processed yellow_tripdata_2024-11.parquet: Kept 1,033,173 trips (Reduced by 71.7%)
# Processed yellow_tripdata_2016-03.parquet: Kept 3,946,892 trips (Reduced by 67.7%)
# Processed yellow_tripdata_2015-10.parquet: Kept 4,090,160 trips (Reduced by 66.8%)
# Processed yellow_tripdata_2019-10.parquet: Kept 2,051,631 trips (Reduced by 71.6%)
# Processed yellow_tripdata_2018-07.parquet: Kept 2,358,521 trips (Reduced by 70.0%)
# Processed yellow_tripdata_2016-11.parquet: Kept 3,206,514 trips (Reduced by 68.3%)
# Processed yellow_tripdata_2018-01.parquet: Kept 2,511,384 trips (Reduced by 71.3%)
# Processed yellow_tripdata_2014-05.parquet: Kept 5,151,841 trips (Reduced by 65.1%)
# Processed yellow_tripdata_2022-01.parquet: Kept 576,189 trips (Reduced by 76.6%)
# Processed yellow_tripdata_2016-08.parquet: Kept 3,206,794 trips (Reduced by 67.7%)
# Processed yellow_tripdata_2020-10.parquet: Kept 285,866 trips (Reduced by 83.0%)
# Processed yellow_tripdata_2021-12.parquet: Kept 799,900 trips (Reduced by 75.1%)
# Processed yellow_tripdata_2014-11.parquet: Kept 4,532,114 trips (Reduced by 65.9%)
# Processed yellow_tripdata_2022-12.parquet: Kept 941,431 trips (Reduced by 72.3%)
# Processed yellow_tripdata_2015-09.parquet: Kept 3,742,948 trips (Reduced by 66.6%)
# Processed yellow_tripdata_2019-02.parquet: Kept 1,994,680 trips (Reduced by 71.7%)
# Processed yellow_tripdata_2023-01.parquet: Kept 821,434 trips (Reduced by 73.2%)
# Processed yellow_tripdata_2015-05.parquet: Kept 4,520,549 trips (Reduced by 65.6%)
# Processed yellow_tripdata_2018-09.parquet: Kept 2,424,501 trips (Reduced by 69.9%)
# Processed yellow_tripdata_2024-09.parquet: Kept 1,075,743 trips (Reduced by 70.4%)
# Processed yellow_tripdata_2024-05.parquet: Kept 1,043,413 trips (Reduced by 72.0%)
# Processed yellow_tripdata_2015-11.parquet: Kept 3,723,246 trips (Reduced by 67.1%)
# Processed yellow_tripdata_2015-07.parquet: Kept 3,927,364 trips (Reduced by 66.0%)
# Processed yellow_tripdata_2021-01.parquet: Kept 167,741 trips (Reduced by 87.8%)
# Processed yellow_tripdata_2017-05.parquet: Kept 3,117,782 trips (Reduced by 69.1%)
# Processed yellow_tripdata_2023-06.parquet: Kept 955,909 trips (Reduced by 71.1%)
# Processed yellow_tripdata_2025-07.parquet: Kept 1,166,373 trips (Reduced by 70.1%)
# Processed yellow_tripdata_2019-06.parquet: Kept 2,077,581 trips (Reduced by 70.2%)
# Processed yellow_tripdata_2023-02.parquet: Kept 788,595 trips (Reduced by 72.9%)
# Processed yellow_tripdata_2024-02.parquet: Kept 847,870 trips (Reduced by 71.8%)
# Processed yellow_tripdata_2017-04.parquet: Kept 3,177,078 trips (Reduced by 68.4%)
# Processed yellow_tripdata_2024-04.parquet: Kept 1,034,498 trips (Reduced by 70.6%)
# Processed yellow_tripdata_2018-06.parquet: Kept 2,674,392 trips (Reduced by 69.3%)
# Processed yellow_tripdata_2018-08.parquet: Kept 2,327,356 trips (Reduced by 70.4%)
# Processed yellow_tripdata_2022-07.parquet: Kept 871,743 trips (Reduced by 72.5%)
# Processed yellow_tripdata_2015-06.parquet: Kept 4,186,435 trips (Reduced by 66.0%)
# Processed yellow_tripdata_2020-11.parquet: Kept 228,993 trips (Reduced by 84.8%)
# Processed yellow_tripdata_2017-10.parquet: Kept 2,956,698 trips (Reduced by 69.7%)
# Processed yellow_tripdata_2019-08.parquet: Kept 1,760,431 trips (Reduced by 71.0%)
# Processed yellow_tripdata_2016-09.parquet: Kept 3,292,372 trips (Reduced by 67.5%)
# Processed yellow_tripdata_2019-11.parquet: Kept 1,987,821 trips (Reduced by 71.1%)
# Processed yellow_tripdata_2014-06.parquet: Kept 4,821,908 trips (Reduced by 65.1%)
# Processed yellow_tripdata_2023-03.parquet: Kept 941,462 trips (Reduced by 72.3%)
# Processed yellow_tripdata_2016-02.parquet: Kept 3,612,076 trips (Reduced by 68.2%)
# Processed yellow_tripdata_2021-04.parquet: Kept 393,109 trips (Reduced by 81.9%)
# Processed yellow_tripdata_2015-03.parquet: Kept 4,475,152 trips (Reduced by 66.5%)
# Processed yellow_tripdata_2020-06.parquet: Kept 91,009 trips (Reduced by 83.4%)
# Processed yellow_tripdata_2021-06.parquet: Kept 659,441 trips (Reduced by 76.7%)
# Processed yellow_tripdata_2017-03.parquet: Kept 3,231,762 trips (Reduced by 68.6%)
# Processed yellow_tripdata_2020-03.parquet: Kept 748,354 trips (Reduced by 75.1%)
# Processed yellow_tripdata_2014-07.parquet: Kept 4,483,303 trips (Reduced by 65.8%)
# Processed yellow_tripdata_2016-07.parquet: Kept 3,446,866 trips (Reduced by 66.5%)
# Processed yellow_tripdata_2024-07.parquet: Kept 856,212 trips (Reduced by 72.2%)
# Processed yellow_tripdata_2022-10.parquet: Kept 1,034,769 trips (Reduced by 71.8%)
# Processed yellow_tripdata_2025-01.parquet: Kept 970,360 trips (Reduced by 72.1%)
# Processed yellow_tripdata_2025-06.parquet: Kept 1,341,647 trips (Reduced by 69.0%)
# Error processing yellow_tripdata_2021-10.parquet: Could not open Parquet input source '<Buffer>': Parquet file size is 0 bytes
# Processed yellow_tripdata_2016-12.parquet: Kept 3,408,880 trips (Reduced by 67.4%)
# Processed yellow_tripdata_2014-01.parquet: Kept 4,550,300 trips (Reduced by 67.0%)
# Processed yellow_tripdata_2014-12.parquet: Kept 4,437,607 trips (Reduced by 66.2%)
#
# Filtering complete. All files now contain only night-time trips.

# %%
import glob
from google.colab import files

parquet_files = glob.glob('yellow_tripdata_*.parquet')

if not parquet_files:
    print("No parquet files found to download.")
else:
    print(f"Starting download for {len(parquet_files)} files...")
    for file_path in sorted(parquet_files):
        print(f"Downloading: {file_path}")
        files.download(file_path)
# Out:
# Starting download for 144 files...
# Downloading: yellow_tripdata_2014-01.parquet
# Downloading: yellow_tripdata_2014-02.parquet
# Downloading: yellow_tripdata_2014-03.parquet
# Downloading: yellow_tripdata_2014-04.parquet
# Downloading: yellow_tripdata_2014-05.parquet
# Downloading: yellow_tripdata_2014-06.parquet
# Downloading: yellow_tripdata_2014-07.parquet
# Downloading: yellow_tripdata_2014-08.parquet
# Downloading: yellow_tripdata_2014-09.parquet
# Downloading: yellow_tripdata_2014-10.parquet
# Downloading: yellow_tripdata_2014-11.parquet
# Downloading: yellow_tripdata_2014-12.parquet
# Downloading: yellow_tripdata_2015-01.parquet
# Downloading: yellow_tripdata_2015-02.parquet
# Downloading: yellow_tripdata_2015-03.parquet
# Downloading: yellow_tripdata_2015-04.parquet
# Downloading: yellow_tripdata_2015-05.parquet
# Downloading: yellow_tripdata_2015-06.parquet
